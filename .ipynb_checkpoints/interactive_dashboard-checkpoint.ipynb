# %%
pip install dash
# Out:
# Requirement already satisfied: dash in /opt/anaconda3/lib/python3.11/site-packages (2.18.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (5.19.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.11/site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from dash) (4.9.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in /opt/anaconda3/lib/python3.11/site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.11/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from dash) (68.2.2)
# Requirement already satisfied: Jinja2>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from plotly>=5.0.0->dash) (23.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->dash) (2024.2.2)
# Requirement already satisfied: six>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from retrying->dash) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing required libraries 
import dash 
import dash_core_components as dcc     
import dash_html_components as html

# %%
solar_capability = pd.read_csv("installed-solar-pv-capacity.csv")
solar_consumtion = pd.read_csv("solar-energy-consumption.csv")

# %%
solar_capability = solar_capability.rename(columns={'Solar energy capacity - GW': 'capability_gw'})
solar_capability = solar_capability.loc[solar_capability['Entity'].isin(["Vietnam", "Australia", "Japan", "Singapore"])]
solar_capability
# Out:
#          Entity Code  Year  capability_gw
# 262   Australia  AUS  2000       0.025000
# 263   Australia  AUS  2001       0.029000
# 264   Australia  AUS  2002       0.034000
# 265   Australia  AUS  2003       0.039400
# 266   Australia  AUS  2004       0.046400
# ...         ...  ...   ...            ...
# 4197    Vietnam  VNM  2018       0.104992
# 4198    Vietnam  VNM  2019       4.993491
# 4199    Vietnam  VNM  2020      16.660492
# 4200    Vietnam  VNM  2021      16.660492
# 4201    Vietnam  VNM  2022      18.474491
#
# [84 rows x 4 columns]

# %%
# rename column
solar_consumtion = solar_consumtion.rename(columns={'Electricity from solar - TWh': 'from_solar_twh'})  
# solar_consumtion
# select data
solar_consumtion = solar_consumtion.loc[solar_consumtion['Entity'].isin(["Vietnam", "Australia", "Japan", "Singapore"])]
solar_consumtion
# Out:
#          Entity Code  Year  from_solar_twh
# 523   Australia  AUS  1990         0.00000
# 524   Australia  AUS  1991         0.00545
# 525   Australia  AUS  1992         0.01210
# 526   Australia  AUS  1993         0.01460
# 527   Australia  AUS  1994         0.01740
# ...         ...  ...   ...             ...
# 8007    Vietnam  VNM  2019         5.25000
# 8008    Vietnam  VNM  2020        10.86000
# 8009    Vietnam  VNM  2021        25.78000
# 8010    Vietnam  VNM  2022        26.37000
# 8011    Vietnam  VNM  2023        25.46000
#
# [199 rows x 4 columns]

# %%
app = dash.Dash() 

app.layout = html.Div(children =[ 
	html.H1("Dash Tutorial"), 
	dcc.Graph( 
		id ="example", 
		figure ={ 
			'data':[ 
					   {'x': solar_consumtion.Code,
						'y': solar_consumtion.from_solar_twh, 
						'type':'bar', 
						'name':'Consumtion',
                        'marker_color' : "red"}, 
					{'x': solar_capability.Code,
						'y':solar_capability.capability_gw, 
						'type':'bar', 
						'name':'Capacity'} 
				], 
			'layout':{ 
				'title': "Solar Consumption and Capacity"
			} 
		} 
	) 
]) 


if __name__ == '__main__': 
	app.run_server()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Out:
#   Cell In[140], line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
pip install facebook-scraper
# Out:
# Requirement already satisfied: facebook-scraper in /opt/anaconda3/lib/python3.11/site-packages (0.2.59)
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (1.2.0)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.5 in /opt/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (3.0.6)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from facebook-scraper) (0.10.0)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2.8.2)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2023.10.3)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.31.0)
# Requirement already satisfied: pyquery in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.1)
# Requirement already satisfied: fake-useragent in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.5.1)
# Requirement already satisfied: parse in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.20.2)
# Requirement already satisfied: bs4 in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (0.0.2)
# Requirement already satisfied: w3lib in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in /opt/anaconda3/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.4.4)
# Requirement already satisfied: certifi>=2023 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2024.2.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (7.0.1)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (11.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.26.20)
# Requirement already satisfied: websockets<11.0,>=10.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (10.4)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil->dateparser<2.0.0,>=1.0.0->facebook-scraper) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.4)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.17.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.11/site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from facebook_scraper import get_posts

# Define your cookies
cookies = {
    'c_user': '100002542360398',
    'xs': '8%3A1E-jpSZF1MpwpA%3A2%3A1716186173%3A-1%3A11897%3A%3AAcVOiFdhJq8S6JjaymBwPhBIOCcstAmBJ8iURrUkf238'
}

listposts = []


for post in get_posts('Super Solar Energy', 
                      pages=10, 
                      options={'comments': True},
                      cookies=cookies):
    print(post)
    listposts.append(post)
    print('Number of posts: {}'.format(len(listposts)))
